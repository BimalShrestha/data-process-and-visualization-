# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalShrestha/data-process-and-visualization-/blob/main/Project_proposal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Project proposal
#
# ##Bimal Shrestha

# %% [markdown]
# For the recent visualization i want to write about the highest paid athlete in the world. As we all know there are many athletes representing different sports and skills. They are paid differently too depending upon their popularity or skill sets.
# ##What I expect in the data and visualizations:
# In this visualization you can expect how the changes of atheletes representing their repective sports through out the years and how salary is not the only income that the athletes are making through out the couse of like 20 years.
# ##Why is this timely?
# I think this is timely because nowadays having good skill sets only will not determine how much you gonna be paid. You got to be more advertisable too. I will also try to show how most athlete like UFC are underpaid where as top of list of highest earning was a UFC fighter.
# ##Why is this important?
# Im really interested in this topic because sports and athletes are being like a popularity contest nowdays. And i hope i can prove this by this project.
# ##Why is this appropriate?
# This is appropriate because we are somehow related to sports in our lives. Many of us idolize various athelete and look up to them. This is list of which atheletes are making more money and whom are underpaid. There are various categories that influence thier income and i hope i can do a good job on where they got thier income and why.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# link to data set
# https://hugequiz.com/quizzes/forbes-highest-paid-athletes-by-year/
# https://www.visualcapitalist.com/highest-paid-athletes-2021/
# https://www.forbes.com/athletes/
