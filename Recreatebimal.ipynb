# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalShrestha/data-process-and-visualization-/blob/main/Recreatebimal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Processing Visualization
# #Bimal Shrestha
# #Recreate Project Proposal

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://www.statista.com/chart/14130/the-worlds-highest-paid-athletes/
# link to the chart.
# https://www.kaggle.com/datasets/darinhawley/forbes-high-paid-athletes-19902021#:~:text=calendar_view_week-,forbesathletesv2,-.csv
# link to data set

# %% [markdown]
# i would like to recreate the above graph. Which is the income of the highest earning athletes. The color coding of on and off the field is really well done. They graph also shows different sports and their nationality really well. Desciption of the amount of money they made is also very well done. I also like how the graph increases horizontally and not vertically which make it look more presentable.
#
#
#
#
# I would definetely have problem to make it as presentable as this one. Cause this graph is more pleasing to eye which might not be the case for me. Color coding on and off the field income might be challenging. Including Image icon to differentiate sports and nationality might be challenging as well. All in all i want this graph to be understandable once you give it a glance. So, i will try to replicate this graph as much as possible.
