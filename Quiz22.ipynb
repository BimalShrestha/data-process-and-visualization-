# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalShrestha/data-process-and-visualization-/blob/main/Quiz22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Bimal Shrestha

# %% [markdown]
#  Head over to Oklahaoma Research Day. Spend some time looking at three posters that include statistical charts or graphs. Include links to each. Discuss the strengths and weaknesses of each. Do they display excellence or do they lie?

# %% [markdown]
# ![uco.png](data:image/png;base64,...)

# %% [markdown]
# Here is the link for the above presentation: https://symposium.foragerone.com/okrd22/presentations/37203

# %% [markdown]
# I chose UCO because i studied there for 4 semesters. I was fascinated to see how they calculated the realtion between the rodent and lunar light emission. They only used cameras and bait as equipments. For data analysis they used chi-square analysis for equal analyss for different moon. But the bar graph shows that there is a significant increase in the nocturnal activities of rodents during the New Moon and Waxing/waning cresent moon phases.
