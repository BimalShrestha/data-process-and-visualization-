# %% [markdown]
# <a href="https://colab.research.google.com/github/BimalShrestha/data-process-and-visualization-/blob/main/dataexam3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exam 3
# ## Bimal Shrestha

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Imoorting libraries.

# %% [markdown]
# # References
#
# https://github.com/nurfnick/Data_Viz/
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.bar.html
#
# https://pandas.pydata.org/docs/reference/api/pandas.Categorical.__array__.html
#
# https://pandas.pydata.org/docs/reference/frame.html
#
# https://thecodingbot.com
#
# I attest that the resources above were the only ones utilized in completing
# the exam and the work included is my own and no one else from the course

# %% [markdown]
# #1)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nurfnick/Data_Viz/main/worldCupPlayer.csv')
df
# Out:
#      Unnamed: 0  Rank                player           club  age   Apps  Mins  \
# 0             0     1          Hakim Ziyech           Ajax   25     34  3043
# 1             2     2   Alireza Jahanbakhsh     AZ Alkmaar   24     33  2840
# 2             4     3        Hirving Lozano  PSV Eindhoven   22     29  2350
# 3             6    11          Lasse Schone           Ajax   32  27(3)  2350
# 4            10    25        Santiago Arias  PSV Eindhoven   26     30  2664
# ..          ...   ...                   ...            ...  ...    ...   ...
# 598        1150   200    Giancarlo Gonzalez        Bologna   30     22  1858
# 599        1152   217  Stephan Lichtsteiner       Juventus   34  21(6)  1715
# 600        1154   235        Dawid Kownacki      Sampdoria   21  6(16)   811
# 601        1156   265     Emil Hallfredsson        Udinese   33  8(11)   761
# 602        1158   269         Marcus Rohden        Crotone   27  20(6)  1637
#
#      Goals  Assists  Yel  Red  SpG    PS AerialsWon  MotM  Rating  nationality
# 0        9       15    4    0  4.9  75.4        0.2     9    8.21      Morocco
# 1       21       12    3    0  4.3  73.4        0.7    14    8.20         Iran
# 2       17        8    4    2  3.4  75.3        0.6     8    7.90       Mexico
# 3       10        3    6    0  1.9  87.0        1.9     2    7.45      Denmark
# 4        3        6    5    0  1.5  82.3          1     2    7.25     Colombia
# ..     ...      ...  ...  ...  ...   ...        ...   ...     ...          ...
# 598      0        0    4    2    -  80.6        2.4     0    6.63   Costa Rica
# 599      0        2    6    0  0.1  82.2        0.9     0    6.59  Switzerland
# 600      5        1    0    0    1  75.4        1.4     0    6.51       Poland
# 601      0        0    5    0  0.1  88.5        0.6     0    6.39      Iceland
# 602      2        0    2    0  0.8  67.6        0.8     0    6.35       Sweden
#
# [603 rows x 17 columns]

# %%
df['nationality'].str.contains('Portugal').any()
# Out:
# True

# %% [markdown]
# This world cup i am supporting Potugal because i am a huge Ronaldo fan. They have a really good squad this year and they have never won a world cup. I am using str.contains to search for portugal.

# %% [markdown]
# ### b) Show a table with all the data about your favorite club or nationality. Include some description about an interesting fact in the data

# %%
d=df.loc[df['nationality']=='Portugal']
d
# Out:
#      Unnamed: 0  Rank             player              club  age    Apps  Mins  \
# 58       0        0    2    0  0.3  91.1        2.3     0    7.30    Portugal
# 59       1        1    3    0  0.9  88.2        1.5     1    7.25    Portugal
# 60       0        0    1    0  0.4  87.8          1     0    6.56    Portugal
# 79       1        0    0    0  1.8  86.9        0.8     0    7.16    Portugal
# 80       8        8    3    1  1.5  83.3        0.3     4    7.40    Portugal
# 81       1        1    2    0  1.2  84.0          -     0    6.77    Portugal
# 95       6        0    1    0  2.1  78.7        0.8     2    7.05    Portugal
# 96       2        0    0    0  1.5  77.0          1     0    6.35    Portugal
# 137      0        0    0    0    -  65.5        0.1     0    6.81    Portugal
# 138      0        0    1    0    -  75.8        0.2     1    6.92    Portugal
# 151      0        0    0    0    -  72.1          -     0    6.65    Portugal
# 152      0        0    4    0    -  70.7        0.2     1    6.76    Portugal
# 153      0        0    0    0    -  57.7          -     0    6.61    Portugal
# 196     26        5    1    0  6.6  81.6        1.3     7    7.94    Portugal
# 197     15        3    2    0  6.3  81.4        1.7     4    8.12    Portugal
# 217      5        9    2    0  1.8  79.3        0.3     3    7.16    Portugal
# 337      1        0    3    0  0.3  84.1          3     0    6.99    Portugal
# 342      0        0    1    0  0.4  75.6          -     0    6.21    Portugal
# 343      1        1    4    0  1.3  84.5        0.1     0    6.48    Portugal
# 344      2        1    4    0  0.7  84.5        3.8     2    7.11    Portugal
# 345      0        0    2    0  0.5  71.9        3.5     0    7.25    Portugal
# 356      0        0    0    0  0.9  81.4        2.1     0    6.58    Portugal
# 371      1        6    6    0  0.7  86.3        0.8     2    7.11    Portugal
# 372      0        1    1    0  0.5  80.7        0.5     1    6.63    Portugal
# 488      6        4    0    0  0.7  87.0        0.1     1    6.79    Portugal
# 489      1        2    1    0  1.1  85.7        0.3     0    7.20    Portugal
# 510      0        3    3    0  0.7  73.3          1     0    6.57    Portugal
# 516      2        4    3    0  0.7  80.3          1     3    7.59    Portugal
# 517      0        2    1    0  0.3  76.9        0.6     0    6.96    Portugal
# 522      3        0    4    0  0.4  85.2        1.9     0    6.95    Portugal
# 535      0        0    5    0    -  66.1        0.3     3    6.91    Portugal
# 590      2        4    8    1  0.3  87.8        0.7     1    6.88    Portugal

# %% [markdown]
# Using .loc[ ] to acces rows and columns by label. We can see that Cristiano Ronaldos numbers are insane. He also holds the record of most goals scored ever.

# %%
d['player'].where(d['Goals'] >= 5)
# Out:
# 27                   NaN
# 28       Bruno Fernandes
# 29                   NaN
# 39      Manuel Fernandes
# 40      Manuel Fernandes
# 58                   NaN
# 59                   NaN
# 60                   NaN
# 79                   NaN
# 80        Gelson Martins
# 81                   NaN
# 95           Andre Silva
# 96                   NaN
# 137                  NaN
# 138                  NaN
# 151                  NaN
# 152                  NaN
# 153                  NaN
# 196    Cristiano Ronaldo
# 197    Cristiano Ronaldo
# 217       Goncalo Guedes
# 337                  NaN
# 342                  NaN
# 343                  NaN
# 344                  NaN
# 345                  NaN
# 356                  NaN
# 371                  NaN
# 372                  NaN
# 488       Bernardo Silva
# 489                  NaN
# 510                  NaN
# 516                  NaN
# 517                  NaN
# 522                  NaN
# 535                  NaN
# 590                  NaN
# Name: player, dtype: object

# %% [markdown]
# Looking for players who atleast scored 5 goals or more for portugal. & players were found.

# %% [markdown]
# ### c) Create a histogram of the ‘Goals’.

# %%
data = df.Goals.plot.hist(bins = 20, title = "Histogram of Goals") 
data.set_xlabel("Goals")
data.set_ylabel("Players")
# Out:
# Text(0, 0.5, 'Players')

# %% [markdown]
# ### d) Create a histogram of the ‘Goals’ and ‘Assists’ on the same axis.

# %%
df1=df[['Goals','Assists']].plot.hist(title="Histogram of Goals and Assist")
df1.set_xlabel("Goals and assists")
df1.set_ylabel("Players")
# Out:
# Text(0, 0.5, 'Players')

# %% [markdown]
# ### e) Create a barchart for most goals scored by nationality.

# %%
df2 = df.groupby(['nationality'])['Goals'].sum()
df2.plot(kind='bar', title="Barchart of most Goals by nationality").set_ylabel("Goals")
plt.show()

# %% [markdown]
# ### f) Create a boxplot of ‘Yel’ (yellow cards) by nationality.

# %%
df.boxplot(by="nationality", column="Yel", rot=90).set_ylabel("No. of Yellow card")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))
# Text(0, 0.5, 'No. of Yellow card')

# %% [markdown]
# ### g) Create ‘Goals’ and ‘Assists’ as scatter. Signify your favorite club or nationality in some way on the scatterplot. You may need to add a new column to the dataset to do so

# %%
sns.relplot(data=df, x = 'Goals', y= 'Assists' )
plt.title('A scatterplot of goals and assists')
# Out:
# Text(0.5, 1.0, 'A scatterplot of goals and assists')

# %% [markdown]
# ### h) Create stacked barplot of goals and assists of French National Team. (they won this tourney!) Be sure to comment on why it is appropriate to stack goals and assists.

# %%
df['nationality'].str.contains('France').any()
df1=df[['Goals','Assists']].plot.bar(title="Goals and assist of France national team")
df1.set_xlabel("Goals and assists")
df1.set_ylabel("Players")
# Out:
# Text(0, 0.5, 'Players')

# %% [markdown]
# It is approriate to stack goals and assists because it is the most determining factor that wins games in football and the data of french national team shows that.

# %% [markdown]
# ###i) Create a correlation heatmap of the entire dataset.

# %%
ax = sns.heatmap(df.corr(),vmin = -1)
ax.set(title = 'Correlation Heatmap of entire dataset')

plt.show()

# %% [markdown]
# ## 2)

# %% [markdown]
# (a) Approximately how long did you work on this exam?
#
#  Ans: This took me about 3 hrs with frequents breaks.
#
# (b) Which was the hardest and easiest topic from this section?
#
#  Ans: it was i for me.
#
# (c) Which method of visualization are you still unclear what it might show?
#
# Ans: Rain cloud.
